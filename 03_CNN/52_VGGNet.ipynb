# %% [markdown]
# # VGGNet

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
vgg = VGG16()
vgg.summary()
# Out:
# ...
# 553467904/553467096 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %%
# !unzip -qq animal.zip -d animals

# %%
import numpy as np
from PIL import Image

img = np.array(Image.open("animals/animal/cat01.jpg").resize((224, 224)))

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# Egyptian_cat (79.76%)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = np.array(Image.open("animals/animal/pig01.jpg").resize((224, 224)))

plt.imshow(img)
plt.axis('off')
plt.show()

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# hog (98.90%)

# %%
img = np.array(Image.open("animals/animal/turtle01.jpg").resize((224, 224)))

plt.imshow(img)
plt.axis('off')
plt.show()

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# leatherback_turtle (45.85%)

# %%
img = np.array(Image.open("animals/animal/tiger01.jpg").resize((224, 224)))

plt.imshow(img)
plt.axis('off')
plt.show()

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# tiger (93.93%)

# %%
img = np.array(Image.open("animals/animal/koala01.jpg").resize((224, 224)))

plt.imshow(img)
plt.axis('off')
plt.show()

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# koala (95.06%)
