# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset: 개, 고양이 구분
# ### Dog Image: 12,500개, Cat Image: 12,500개, 총 25,000개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp drive/MyDrive/train.zip .

# %%
# !unzip -qq train.zip -d dogs-vs-cats

# %%
# !pwd
# Out:
# /content

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
## Definition to load all our dog images
def load_dogs():
    print('Loading all dog images\n')
    dog_path = os.path.join(path, 'dog*')
    for dog_img in glob(dog_path):
        dog = cv2.imread(dog_img)
        dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
        dog = cv2.resize(dog, (ROW, COL))
        dog = image.img_to_array(dog)
        dogs.append(dog)
    print('All dog images loaded')

# %%
## Definition to load all our cat images
def load_cats():
    print('Loading all cat images\n')
    cat_path = os.path.join(path, 'cat*')
    for cat_img in glob(cat_path):
        cat = cv2.imread(cat_img)
        cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
        cat = cv2.resize(cat, (ROW, COL))
        cat = image.img_to_array(cat)
        cats.append(cat)
    print('All cat images loaded')

# %%
## in case we want to see if our images was saved correctly in arrays we can use those codes
def show_dogs():
    plt.figure(figsize=(12,4))    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(dogs))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        
        plt.axis('off')
        plt.title(f'Supposed to be a {classes[0]}')        
    plt.show()

# %%
def show_cats():
    plt.figure(figsize=(12,4))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(cats))
        plt.imshow(img, cmap=plt.get_cmap('gray'))

        plt.axis('off')
        plt.title(f'Supposed to be a {classes[1]}')
    plt.show()

# %%
load_dogs()
# Out:
# Loading all dog images
#
# All dog images loaded

# %%
load_cats()
# Out:
# Loading all cat images
#
# All cat images loaded

# %%
classes = ['dog', 'cat']

# %%
show_dogs()

# %%
show_cats()

# %%
## just change the labels for 0 and 1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32')/255
cats = np.asarray(cats).astype('float32')/255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X = np.concatenate((dogs, cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X.shape, y.shape
# Out:
# ((25000, 96, 96, 1), (25000,))

# %%
IMG_CHANNEL = 1
BATCH_SIZE = 128
N_EPOCH = 30
VERBOSE = 2
VALIDAION_SPLIT = 0.2
OPTIM = Adam()
N_CLASSES = len(classes)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=seed
)

# %%
## One-Hot Encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, N_CLASSES)
y_test = to_categorical(y_test, N_CLASSES)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, IMG_CHANNEL), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(N_CLASSES, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=OPTIM, metrics=['accuracy'])

# %%
## to save checkpoint to use latter
modelpath = 'model/dogs_vs_cats_redux_checkpoint.h5'
checkpoint = ModelCheckpoint(filepath=modelpath, save_best_only=True, verbose=1)

# %%
history = model.fit(X_train, y_train, 
                    batch_size=BATCH_SIZE, epochs=N_EPOCH, 
                    validation_split=VALIDAION_SPLIT,
                    verbose=VERBOSE, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 125/125 - 17s - loss: 0.7052 - accuracy: 0.5263 - val_loss: 0.6944 - val_accuracy: 0.5005
#
# Epoch 00001: val_loss improved from inf to 0.69441, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 2/30
# 125/125 - 9s - loss: 0.6891 - accuracy: 0.5270 - val_loss: 0.6498 - val_accuracy: 0.6538
#
# Epoch 00002: val_loss improved from 0.69441 to 0.64979, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 3/30
# 125/125 - 9s - loss: 0.6169 - accuracy: 0.6666 - val_loss: 0.5579 - val_accuracy: 0.7100
#
# Epoch 00003: val_loss improved from 0.64979 to 0.55791, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 4/30
# 125/125 - 9s - loss: 0.5316 - accuracy: 0.7333 - val_loss: 0.5068 - val_accuracy: 0.7448
#
# Epoch 00004: val_loss improved from 0.55791 to 0.50680, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 5/30
# 125/125 - 9s - loss: 0.4646 - accuracy: 0.7800 - val_loss: 0.4730 - val_accuracy: 0.7732
#
# Epoch 00005: val_loss improved from 0.50680 to 0.47302, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 6/30
# 125/125 - 10s - loss: 0.4184 - accuracy: 0.8023 - val_loss: 0.4571 - val_accuracy: 0.7920
#
# Epoch 00006: val_loss improved from 0.47302 to 0.45708, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 7/30
# 125/125 - 10s - loss: 0.3712 - accuracy: 0.8322 - val_loss: 0.4496 - val_accuracy: 0.7940
#
# Epoch 00007: val_loss improved from 0.45708 to 0.44964, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 8/30
# 125/125 - 10s - loss: 0.3241 - accuracy: 0.8578 - val_loss: 0.4652 - val_accuracy: 0.7890
#
# Epoch 00008: val_loss did not improve from 0.44964
# Epoch 9/30
# 125/125 - 10s - loss: 0.2619 - accuracy: 0.8891 - val_loss: 0.4397 - val_accuracy: 0.8163
#
# Epoch 00009: val_loss improved from 0.44964 to 0.43969, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 10/30
# 125/125 - 10s - loss: 0.2079 - accuracy: 0.9143 - val_loss: 0.5318 - val_accuracy: 0.8000
#
# Epoch 00010: val_loss did not improve from 0.43969
# Epoch 11/30
# 125/125 - 10s - loss: 0.1533 - accuracy: 0.9395 - val_loss: 0.6483 - val_accuracy: 0.8035
#
# Epoch 00011: val_loss did not improve from 0.43969
# Epoch 12/30
# 125/125 - 10s - loss: 0.1244 - accuracy: 0.9521 - val_loss: 0.6069 - val_accuracy: 0.8152
#
# Epoch 00012: val_loss did not improve from 0.43969
# Epoch 13/30
# 125/125 - 10s - loss: 0.0937 - accuracy: 0.9649 - val_loss: 0.6810 - val_accuracy: 0.8102
#
# Epoch 00013: val_loss did not improve from 0.43969
# Epoch 14/30
# 125/125 - 10s - loss: 0.0832 - accuracy: 0.9707 - val_loss: 0.6608 - val_accuracy: 0.8065
#
# Epoch 00014: val_loss did not improve from 0.43969
# Epoch 15/30
# 125/125 - 10s - loss: 0.0679 - accuracy: 0.9777 - val_loss: 0.7504 - val_accuracy: 0.8173
#
# Epoch 00015: val_loss did not improve from 0.43969
# Epoch 16/30
# 125/125 - 10s - loss: 0.0578 - accuracy: 0.9818 - val_loss: 0.8419 - val_accuracy: 0.7990
#
# Epoch 00016: val_loss did not improve from 0.43969
# Epoch 17/30
# 125/125 - 10s - loss: 0.0509 - accuracy: 0.9838 - val_loss: 0.7621 - val_accuracy: 0.8123
#
# Epoch 00017: val_loss did not improve from 0.43969
# Epoch 18/30
# 125/125 - 10s - loss: 0.0368 - accuracy: 0.9876 - val_loss: 0.8394 - val_accuracy: 0.8163
#
# Epoch 00018: val_loss did not improve from 0.43969
# Epoch 19/30
# 125/125 - 10s - loss: 0.0359 - accuracy: 0.9878 - val_loss: 0.8589 - val_accuracy: 0.8163
#
# Epoch 00019: val_loss did not improve from 0.43969
# Epoch 20/30
# 125/125 - 10s - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.8273 - val_accuracy: 0.8170
#
# Epoch 00020: val_loss did not improve from 0.43969
# Epoch 21/30
# 125/125 - 10s - loss: 0.0356 - accuracy: 0.9879 - val_loss: 0.8078 - val_accuracy: 0.8110
#
# Epoch 00021: val_loss did not improve from 0.43969
# Epoch 22/30
# 125/125 - 10s - loss: 0.0347 - accuracy: 0.9895 - val_loss: 0.9368 - val_accuracy: 0.8167
#
# Epoch 00022: val_loss did not improve from 0.43969
# Epoch 23/30
# 125/125 - 10s - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.9569 - val_accuracy: 0.8140
#
# Epoch 00023: val_loss did not improve from 0.43969
# Epoch 24/30
# 125/125 - 10s - loss: 0.0279 - accuracy: 0.9915 - val_loss: 1.0243 - val_accuracy: 0.8207
#
# Epoch 00024: val_loss did not improve from 0.43969
# Epoch 25/30
# 125/125 - 10s - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.8863 - val_accuracy: 0.8245
#
# Epoch 00025: val_loss did not improve from 0.43969
# Epoch 26/30
# 125/125 - 10s - loss: 0.0297 - accuracy: 0.9908 - val_loss: 1.0733 - val_accuracy: 0.8117
#
# Epoch 00026: val_loss did not improve from 0.43969
# Epoch 27/30
# 125/125 - 10s - loss: 0.0263 - accuracy: 0.9921 - val_loss: 0.9474 - val_accuracy: 0.8148
#
# Epoch 00027: val_loss did not improve from 0.43969
# Epoch 28/30
# 125/125 - 10s - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.9244 - val_accuracy: 0.8133
#
# Epoch 00028: val_loss did not improve from 0.43969
# Epoch 29/30
# 125/125 - 10s - loss: 0.0171 - accuracy: 0.9947 - val_loss: 1.1057 - val_accuracy: 0.8075
#
# Epoch 00029: val_loss did not improve from 0.43969
# Epoch 30/30
# 125/125 - 10s - loss: 0.0240 - accuracy: 0.9922 - val_loss: 1.0618 - val_accuracy: 0.8152
#
# Epoch 00030: val_loss did not improve from 0.43969

# %%
acc = model.evaluate(X_test, y_test, verbose=2)[1]
print('MODEL ACCURACY: %.5f' % acc)
# Out:
# 157/157 - 1s - loss: 1.0154 - accuracy: 0.8226
# MODEL ACCURACY: 0.82260

# %%
from tensorflow.keras.models import load_model
best_model = load_model(modelpath)
acc = best_model.evaluate(X_test, y_test, verbose=2)[1]
print('Best model accuracy: %.5f' % acc)
# Out:
# 157/157 - 1s - loss: 0.4311 - accuracy: 0.8266
# Best model accuracy: 0.82660

# %%
# 검증셋
y_vloss = history.history['val_loss']
y_vacc = history.history['val_accuracy']

# 학습셋
y_loss = history.history['loss']
y_acc = history.history['accuracy']

# %%
x_len = np.arange(1, len(y_loss)+1)
fig, ax0 = plt.subplots(figsize=(10,8))
ax1 = ax0.twinx()
ax0.plot(x_len, y_loss, c="blue", label='train set loss')
ax0.plot(x_len, y_vloss, c="red", label='valid set loss')
ax0.set_ylabel('loss')
ax1.plot(x_len, y_acc, c="darkgreen", label='train set acc')
ax1.plot(x_len, y_vacc, c="magenta", label='valid set acc')
ax1.set_ylabel('accuracy')
ax0.set_xlabel('epoch')
ax0.legend(loc='lower center')
ax1.legend(loc='upper center')
plt.grid()
plt.show()
